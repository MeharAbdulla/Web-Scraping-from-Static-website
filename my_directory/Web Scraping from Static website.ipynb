# %% [markdown]
# # Techniques: HTML parsing, XPath, CSS selectors.
# # ■ Libraries: BeautifulSoup, requests.
# # ■ Project: Build a scraper to extract data from a static website (e.g.,
# # e-commerce product details).

# %%
import numpy as np
import pandas as pd
from bs4 import BeautifulSoup
import requests
import os

# %% [markdown]
# # Scraped Data Cleaning

# %%
def Scrap_page(product_data, products):
    for product in products:
        price = product.find('p', class_="price_color").text.strip()
        name = product.find("h3").find("a")['title']
        stock = product.find("p", class_="instock availability").get_text(strip=True)
        rating_tag = product.find("p", class_="star-rating")
        rating = rating_tag["class"][1] if rating_tag else "No Rating"
        image_src = product.find("div", class_="image_container").find("img")["src"]
        
        product_data.append({
            "Name": name,
            "Rating": rating,
            "Price": price,
            "Images": image_src,
            "Stock": stock
        })

# %% [markdown]
# # Scraping multple pages

# %%
def scrap_multiple_pages(url):
    number_pages = 20
    product_data = []
    
    for page in range(1, number_pages + 1):
        page_url = f"{url}/catalogue/page-{page}.html"
        response = requests.get(page_url)
        response.raise_for_status() 
        soup = BeautifulSoup(response.text, "html.parser")
        products = soup.find_all("article", class_="product_pod")
        Scrap_page(product_data, products)
    
    return product_data

# %% [markdown]
# # Website URL

# %%
url = "https://books.toscrape.com/"
ALL_products = scrap_multiple_pages(url)

# %% [markdown]
# # Gain Data List

# %%
ALL_products
# Out:
# [{'Name': 'A Light in the Attic',
#   'Rating': 'Three',
#   'Price': 'Â£51.77',
#   'Images': '../media/cache/2c/da/2cdad67c44b002e7ead0cc35693c0e8b.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Tipping the Velvet',
#   'Rating': 'One',
#   'Price': 'Â£53.74',
#   'Images': '../media/cache/26/0c/260c6ae16bce31c8f8c95daddd9f4a1c.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Soumission',
#   'Rating': 'One',
#   'Price': 'Â£50.10',
#   'Images': '../media/cache/3e/ef/3eef99c9d9adef34639f510662022830.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Sharp Objects',
#   'Rating': 'Four',
#   'Price': 'Â£47.82',
#   'Images': '../media/cache/32/51/3251cf3a3412f53f339e42cac2134093.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Sapiens: A Brief History of Humankind',
#   'Rating': 'Five',
#   'Price': 'Â£54.23',
#   'Images': '../media/cache/be/a5/bea5697f2534a2f86a3ef27b5a8c12a6.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'The Requiem Red',
#   'Rating': 'One',
#   'Price': 'Â£22.65',
#   'Images': '../media/cache/68/33/68339b4c9bc034267e1da611ab3b34f8.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'The Dirty Little Secrets of Getting Your Dream Job',
#   'Rating': 'Four',
#   'Price': 'Â£33.34',
#   'Images': '../media/cache/92/27/92274a95b7c251fea59a2b8a78275ab4.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'The Coming Woman: A Novel Based on the Life of the Infamous Feminist, Victoria Woodhull',
#   'Rating': 'Three',
#   'Price': 'Â£17.93',
#   'Images': '../media/cache/3d/54/3d54940e57e662c4dd1f3ff00c78cc64.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'The Boys in the Boat: Nine Americans and Their Epic Quest for Gold at the 1936 Berlin Olympics',
#   'Rating': 'Four',
#   'Price': 'Â£22.60',
#   'Images': '../media/cache/66/88/66883b91f6804b2323c8369331cb7dd1.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'The Black Maria',
#   'Rating': 'One',
#   'Price': 'Â£52.15',
#   'Images': '../media/cache/58/46/5846057e28022268153beff6d352b06c.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Starving Hearts (Triangular Trade Trilogy, #1)',
#   'Rating': 'Two',
#   'Price': 'Â£13.99',
#   'Images': '../media/cache/be/f4/bef44da28c98f905a3ebec0b87be8530.jpg',
#   'Stock': 'In stock'},
#  {'Name': "Shakespeare's Sonnets",
#   'Rating': 'Four',
#   'Price': 'Â£20.66',
#   'Images': '../media/cache/10/48/1048f63d3b5061cd2f424d20b3f9b666.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Set Me Free',
#   'Rating': 'Five',
#   'Price': 'Â£17.46',
#   'Images': '../media/cache/5b/88/5b88c52633f53cacf162c15f4f823153.jpg',
#   'Stock': 'In stock'},
#  {'Name': "Scott Pilgrim's Precious Little Life (Scott Pilgrim #1)",
#   'Rating': 'Five',
#   'Price': 'Â£52.29',
#   'Images': '../media/cache/94/b1/94b1b8b244bce9677c2f29ccc890d4d2.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Rip it Up and Start Again',
#   'Rating': 'Five',
#   'Price': 'Â£35.02',
#   'Images': '../media/cache/81/c4/81c4a973364e17d01f217e1188253d5e.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Our Band Could Be Your Life: Scenes from the American Indie Underground, 1981-1991',
#   'Rating': 'Three',
#   'Price': 'Â£57.25',
#   'Images': '../media/cache/54/60/54607fe8945897cdcced0044103b10b6.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Olio',
#   'Rating': 'One',
#   'Price': 'Â£23.88',
#   'Images': '../media/cache/55/33/553310a7162dfbc2c6d19a84da0df9e1.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Mesaerion: The Best Science Fiction Stories 1800-1849',
#   'Rating': 'One',
#   'Price': 'Â£37.59',
#   'Images': '../media/cache/09/a3/09a3aef48557576e1a85ba7efea8ecb7.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Libertarianism for Beginners',
#   'Rating': 'Two',
#   'Price': 'Â£51.33',
#   'Images': '../media/cache/0b/bc/0bbcd0a6f4bcd81ccb1049a52736406e.jpg',
#   'Stock': 'In stock'},
#  {'Name': "It's Only the Himalayas",
#   'Rating': 'Two',
#   'Price': 'Â£45.17',
#   'Images': '../media/cache/27/a5/27a53d0bb95bdd88288eaf66c9230d7e.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'In Her Wake',
#   'Rating': 'One',
#   'Price': 'Â£12.84',
#   'Images': '../media/cache/5d/72/5d72709c6a7a9584a4d1cf07648bfce1.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'How Music Works',
#   'Rating': 'Two',
#   'Price': 'Â£37.32',
#   'Images': '../media/cache/5c/c8/5cc8e107246cb478960d4f0aba1e1c8e.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Foolproof Preserving: A Guide to Small Batch Jams, Jellies, Pickles, Condiments, and More: A Foolproof Guide to Making Small Batch Jams, Jellies, Pickles, Condiments, and More',
#   'Rating': 'Three',
#   'Price': 'Â£30.52',
#   'Images': '../media/cache/9f/59/9f59f01fa916a7bb8f0b28a4012179a4.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Chase Me (Paris Nights #2)',
#   'Rating': 'Five',
#   'Price': 'Â£25.27',
#   'Images': '../media/cache/9c/2e/9c2e0eb8866b8e3f3b768994fd3d1c1a.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Black Dust',
#   'Rating': 'Five',
#   'Price': 'Â£34.53',
#   'Images': '../media/cache/44/cc/44ccc99c8f82c33d4f9d2afa4ef25787.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Birdsong: A Story in Pictures',
#   'Rating': 'Three',
#   'Price': 'Â£54.64',
#   'Images': '../media/cache/af/6e/af6e796160fe63e0cf19d44395c7ddf2.jpg',
#   'Stock': 'In stock'},
#  {'Name': "America's Cradle of Quarterbacks: Western Pennsylvania's Football Factory from Johnny Unitas to Joe Montana",
#   'Rating': 'Three',
#   'Price': 'Â£22.50',
#   'Images': '../media/cache/ef/0b/ef0bed08de4e083dba5e20fdb98d9c36.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Aladdin and His Wonderful Lamp',
#   'Rating': 'Three',
#   'Price': 'Â£53.13',
#   'Images': '../media/cache/d6/da/d6da0371958068bbaf39ea9c174275cd.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Worlds Elsewhere: Journeys Around Shakespeareâ\x80\x99s Globe',
#   'Rating': 'Five',
#   'Price': 'Â£40.30',
#   'Images': '../media/cache/2e/98/2e98c332bf8563b584784971541c4445.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Wall and Piece',
#   'Rating': 'Four',
#   'Price': 'Â£44.18',
#   'Images': '../media/cache/a5/41/a5416b9646aaa7287baa287ec2590270.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'The Four Agreements: A Practical Guide to Personal Freedom',
#   'Rating': 'Five',
#   'Price': 'Â£17.66',
#   'Images': '../media/cache/0f/7e/0f7ee69495c0df1d35723f012624a9f8.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'The Five Love Languages: How to Express Heartfelt Commitment to Your Mate',
#   'Rating': 'Three',
#   'Price': 'Â£31.05',
#   'Images': '../media/cache/38/c5/38c56fba316c07305643a8065269594e.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'The Elephant Tree',
#   'Rating': 'Five',
#   'Price': 'Â£23.82',
#   'Images': '../media/cache/5d/7e/5d7ecde8e81513eba8a64c9fe000744b.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'The Bear and the Piano',
#   'Rating': 'One',
#   'Price': 'Â£36.89',
#   'Images': '../media/cache/cf/bb/cfbb5e62715c6d888fd07794c9bab5d6.jpg',
#   'Stock': 'In stock'},
#  {'Name': "Sophie's World",
#   'Rating': 'Five',
#   'Price': 'Â£15.94',
#   'Images': '../media/cache/65/71/6571919836ec51ed54f0050c31d8a0cd.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Penny Maybe',
#   'Rating': 'Three',
#   'Price': 'Â£33.29',
#   'Images': '../media/cache/12/53/1253c21c5ef3c6d075c5fa3f5fecee6a.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Maude (1883-1993):She Grew Up with the country',
#   'Rating': 'Two',
#   'Price': 'Â£18.02',
#   'Images': '../media/cache/f5/88/f5889d038f5d8e949b494d147c2dcf54.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'In a Dark, Dark Wood',
#   'Rating': 'One',
#   'Price': 'Â£19.63',
#   'Images': '../media/cache/23/85/238570a1c284e730dbc737a7e631ae2b.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Behind Closed Doors',
#   'Rating': 'Four',
#   'Price': 'Â£52.22',
#   'Images': '../media/cache/e1/5c/e15c289ba58cea38519e1281e859f0c1.jpg',
#   'Stock': 'In stock'},
#  {'Name': "You can't bury them all: Poems",
#   'Rating': 'Two',
#   'Price': 'Â£33.63',
#   'Images': '../media/cache/e9/20/e9203b733126c4a0832a1c7885dc27cf.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Slow States of Collapse: Poems',
#   'Rating': 'Three',
#   'Price': 'Â£57.31',
#   'Images': '../media/cache/72/41/72417db983862010ef0c1a25de98c7d7.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Reasons to Stay Alive',
#   'Rating': 'Two',
#   'Price': 'Â£26.41',
#   'Images': '../media/cache/cb/bd/cbbdb0222ee8a0f6ab61657412a15794.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Private Paris (Private #10)',
#   'Rating': 'Five',
#   'Price': 'Â£47.61',
#   'Images': '../media/cache/9d/05/9d0533bae1578846d728a82913b95c26.jpg',
#   'Stock': 'In stock'},
#  {'Name': '#HigherSelfie: Wake Up Your Life. Free Your Soul. Find Your Tribe.',
#   'Rating': 'Five',
#   'Price': 'Â£23.11',
#   'Images': '../media/cache/9c/46/9c463c7631c82401160fd3b554b8f0e1.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Without Borders (Wanderlove #1)',
#   'Rating': 'Two',
#   'Price': 'Â£45.07',
#   'Images': '../media/cache/24/e2/24e2f5c9d325c4004d8190c054da86dd.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'When We Collided',
#   'Rating': 'One',
#   'Price': 'Â£31.77',
#   'Images': '../media/cache/08/04/08044269fc197645268a6197c57e6173.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'We Love You, Charlie Freeman',
#   'Rating': 'Five',
#   'Price': 'Â£50.27',
#   'Images': '../media/cache/5f/15/5f152afdbc42356ecba02f61058a7e5b.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Untitled Collection: Sabbath Poems 2014',
#   'Rating': 'Four',
#   'Price': 'Â£14.27',
#   'Images': '../media/cache/f9/3b/f93b4a650f03a5d21f2436d7813f42c2.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Unseen City: The Majesty of Pigeons, the Discreet Charm of Snails & Other Wonders of the Urban Wilderness',
#   'Rating': 'Four',
#   'Price': 'Â£44.18',
#   'Images': '../media/cache/41/a2/41a20f35adf0caea24f208dc01ad7681.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Unicorn Tracks',
#   'Rating': 'Three',
#   'Price': 'Â£18.78',
#   'Images': '../media/cache/76/8e/768ea5924ac1ef6297c2be9959c796c2.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Unbound: How Eight Technologies Made Us Human, Transformed Society, and Brought Our World to the Brink',
#   'Rating': 'One',
#   'Price': 'Â£25.52',
#   'Images': '../media/cache/4a/3b/4a3b055f9e378a95fedbef55e7bab7ce.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Tsubasa: WoRLD CHRoNiCLE 2 (Tsubasa WoRLD CHRoNiCLE #2)',
#   'Rating': 'One',
#   'Price': 'Â£16.28',
#   'Images': '../media/cache/36/df/36df4caaf1420b1183a8235355d39e69.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Throwing Rocks at the Google Bus: How Growth Became the Enemy of Prosperity',
#   'Rating': 'Three',
#   'Price': 'Â£31.12',
#   'Images': '../media/cache/03/86/038650c9e7517b4baf2a423cd8eed38f.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'This One Summer',
#   'Rating': 'Four',
#   'Price': 'Â£19.49',
#   'Images': '../media/cache/c4/dd/c4ddd9ced89966b0602ec85e00cd5b61.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Thirst',
#   'Rating': 'Five',
#   'Price': 'Â£17.27',
#   'Images': '../media/cache/c4/0a/c40a64f59e7487b1a80a049f6ceb2ba5.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'The Torch Is Passed: A Harding Family Story',
#   'Rating': 'One',
#   'Price': 'Â£19.09',
#   'Images': '../media/cache/33/e5/33e507172541628acfd421503196b578.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'The Secret of Dreadwillow Carse',
#   'Rating': 'One',
#   'Price': 'Â£56.13',
#   'Images': '../media/cache/c4/a2/c4a2a1a026c67bcceb5a411c724d7d0c.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'The Pioneer Woman Cooks: Dinnertime: Comfort Classics, Freezer Food, 16-Minute Meals, and Other Delicious Ways to Solve Supper!',
#   'Rating': 'One',
#   'Price': 'Â£56.41',
#   'Images': '../media/cache/b7/f4/b7f4843dbe062d44be1ffcfa16b2faa4.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'The Past Never Ends',
#   'Rating': 'Four',
#   'Price': 'Â£56.50',
#   'Images': '../media/cache/89/b8/89b850edb01851a91f64ba114b96acb6.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'The Natural History of Us (The Fine Art of Pretending #2)',
#   'Rating': 'Three',
#   'Price': 'Â£45.22',
#   'Images': '../media/cache/5d/7f/5d7f496cdf5e5962a73ecdcc1505c1d5.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'The Nameless City (The Nameless City #1)',
#   'Rating': 'Four',
#   'Price': 'Â£38.16',
#   'Images': '../media/cache/f4/79/f479de5f305c2ac0512702cf7155bb74.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'The Murder That Never Was (Forensic Instincts #5)',
#   'Rating': 'Three',
#   'Price': 'Â£54.11',
#   'Images': '../media/cache/dc/44/dc44f8e2aebac48ca8553814d9b021a8.jpg',
#   'Stock': 'In stock'},
#  {'Name': "The Most Perfect Thing: Inside (and Outside) a Bird's Egg",
#   'Rating': 'Four',
#   'Price': 'Â£42.96',
#   'Images': '../media/cache/d4/8d/d48d5122a15347e9fe2b15ad354d69bf.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'The Mindfulness and Acceptance Workbook for Anxiety: A Guide to Breaking Free from Anxiety, Phobias, and Worry Using Acceptance and Commitment Therapy',
#   'Rating': 'Four',
#   'Price': 'Â£23.89',
#   'Images': '../media/cache/f8/6d/f86d08178e3788563ac17be5aefd29f0.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'The Life-Changing Magic of Tidying Up: The Japanese Art of Decluttering and Organizing',
#   'Rating': 'Three',
#   'Price': 'Â£16.77',
#   'Images': '../media/cache/95/64/95647d6a526bf54120b9445e124794e1.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'The Inefficiency Assassin: Time Management Tactics for Working Smarter, Not Longer',
#   'Rating': 'Five',
#   'Price': 'Â£20.59',
#   'Images': '../media/cache/75/dc/75dce2f5949b407161f37f0af249b018.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'The Gutsy Girl: Escapades for Your Life of Epic Adventure',
#   'Rating': 'One',
#   'Price': 'Â£37.13',
#   'Images': '../media/cache/64/15/641570cd7e7aded53c7d33d78a9629f1.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'The Electric Pencil: Drawings from Inside State Hospital No. 3',
#   'Rating': 'One',
#   'Price': 'Â£56.06',
#   'Images': '../media/cache/2e/23/2e236e23ad52aa74505f224f6552eda8.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'The Death of Humanity: and the Case for Life',
#   'Rating': 'Four',
#   'Price': 'Â£58.11',
#   'Images': '../media/cache/71/df/71df730cf38c232ee58a2e407135f055.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'The Bulletproof Diet: Lose up to a Pound a Day, Reclaim Energy and Focus, Upgrade Your Life',
#   'Rating': 'Three',
#   'Price': 'Â£49.05',
#   'Images': '../media/cache/ee/3e/ee3e219d23e73ba71c79b700f183aaed.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'The Art Forger',
#   'Rating': 'Three',
#   'Price': 'Â£40.76',
#   'Images': '../media/cache/70/fa/70fa6c0437d9c97dbeada6bd32bf9d2c.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'The Age of Genius: The Seventeenth Century and the Birth of the Modern Mind',
#   'Rating': 'One',
#   'Price': 'Â£19.73',
#   'Images': '../media/cache/2d/4e/2d4e358712e6c9f1d3bdd78d1a16e5a8.jpg',
#   'Stock': 'In stock'},
#  {'Name': "The Activist's Tao Te Ching: Ancient Advice for a Modern Revolution",
#   'Rating': 'Five',
#   'Price': 'Â£32.24',
#   'Images': '../media/cache/96/db/96db61bb53930c560fb4c1c62b583816.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Spark Joy: An Illustrated Master Class on the Art of Organizing and Tidying Up',
#   'Rating': 'Four',
#   'Price': 'Â£41.83',
#   'Images': '../media/cache/f3/4f/f34ffb24cc21c9f9f52dad4fd8f3ac21.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Soul Reader',
#   'Rating': 'Two',
#   'Price': 'Â£39.58',
#   'Images': '../media/cache/69/85/69852567cf97264a1442cbc882c84903.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Security',
#   'Rating': 'Two',
#   'Price': 'Â£39.25',
#   'Images': '../media/cache/da/df/dadfac66a89774b46b10225362724c83.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Saga, Volume 6 (Saga (Collected Editions) #6)',
#   'Rating': 'Three',
#   'Price': 'Â£25.02',
#   'Images': '../media/cache/43/ae/43aee83ebb31e2122a7215e413770e5c.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Saga, Volume 5 (Saga (Collected Editions) #5)',
#   'Rating': 'Two',
#   'Price': 'Â£51.04',
#   'Images': '../media/cache/e1/ea/e1ea6cb36e62ae6dc7b805f68ab9a700.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Reskilling America: Learning to Labor in the Twenty-First Century',
#   'Rating': 'Two',
#   'Price': 'Â£19.83',
#   'Images': '../media/cache/97/f8/97f8debeeaaece9603267653076e760f.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Rat Queens, Vol. 3: Demons (Rat Queens (Collected Editions) #11-15)',
#   'Rating': 'Three',
#   'Price': 'Â£50.40',
#   'Images': '../media/cache/f3/ef/f3efd43ae0fa85d9b325d5e8783e7af5.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Princess Jellyfish 2-in-1 Omnibus, Vol. 01 (Princess Jellyfish 2-in-1 Omnibus #1)',
#   'Rating': 'Five',
#   'Price': 'Â£13.61',
#   'Images': '../media/cache/78/0b/780b2c28122750c2c383846155815bf7.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Princess Between Worlds (Wide-Awake Princess #5)',
#   'Rating': 'Five',
#   'Price': 'Â£13.34',
#   'Images': '../media/cache/b7/e8/b7e84b78be3d9bb79b71156a5e5d4e42.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Pop Gun War, Volume 1: Gift',
#   'Rating': 'One',
#   'Price': 'Â£18.97',
#   'Images': '../media/cache/c8/2f/c82f629a31b3f47bdb17ac14aa51076d.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Political Suicide: Missteps, Peccadilloes, Bad Calls, Backroom Hijinx, Sordid Pasts, Rotten Breaks, and Just Plain Dumb Mistakes in the Annals of American Politics',
#   'Rating': 'Two',
#   'Price': 'Â£36.28',
#   'Images': '../media/cache/64/44/6444dacdcb9edaadbbd691524622aeb8.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Patience',
#   'Rating': 'Three',
#   'Price': 'Â£10.16',
#   'Images': '../media/cache/01/72/01726c619a05114dca75bd840095016d.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Outcast, Vol. 1: A Darkness Surrounds Him (Outcast #1)',
#   'Rating': 'Four',
#   'Price': 'Â£15.44',
#   'Images': '../media/cache/cb/00/cb004189f548d75ad430d3ed19e6daa9.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'orange: The Complete Collection 1 (orange: The Complete Collection #1)',
#   'Rating': 'One',
#   'Price': 'Â£48.41',
#   'Images': '../media/cache/03/88/03886a8502ca54dbce0d91c2568ab69d.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Online Marketing for Busy Authors: A Step-By-Step Guide',
#   'Rating': 'One',
#   'Price': 'Â£46.35',
#   'Images': '../media/cache/ea/9b/ea9b2cb8abbb317402e618445bade1e1.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'On a Midnight Clear',
#   'Rating': 'Three',
#   'Price': 'Â£14.07',
#   'Images': '../media/cache/a1/14/a114d70e7babf110ba42a389078e9a45.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Obsidian (Lux #1)',
#   'Rating': 'Two',
#   'Price': 'Â£14.86',
#   'Images': '../media/cache/fc/72/fc72f158554b4b4164701e1dfa1153c7.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'My Paris Kitchen: Recipes and Stories',
#   'Rating': 'Two',
#   'Price': 'Â£33.37',
#   'Images': '../media/cache/f5/65/f565af3d9dd20a1ad72a1e7c4157387d.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Masks and Shadows',
#   'Rating': 'Two',
#   'Price': 'Â£56.40',
#   'Images': '../media/cache/ff/e8/ffe81bf98f8386ef29e193abfb6f9c1e.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Mama Tried: Traditional Italian Cooking for the Screwed, Crude, Vegan, and Tattooed',
#   'Rating': 'Four',
#   'Price': 'Â£14.02',
#   'Images': '../media/cache/10/c6/10c61093002db1fec4089d8076678624.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Lumberjanes, Vol. 2: Friendship to the Max (Lumberjanes #5-8)',
#   'Rating': 'Two',
#   'Price': 'Â£46.91',
#   'Images': '../media/cache/d3/15/d3158e8d3546fb90cced3c1d44a92a34.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Lumberjanes, Vol. 1: Beware the Kitten Holy (Lumberjanes #1-4)',
#   'Rating': 'Three',
#   'Price': 'Â£45.61',
#   'Images': '../media/cache/7e/a0/7ea062007ef00107e3c16d336b41fab2.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Lumberjanes Vol. 3: A Terrible Plan (Lumberjanes #9-12)',
#   'Rating': 'Two',
#   'Price': 'Â£19.92',
#   'Images': '../media/cache/5f/b1/5fb1bf88dcfda795606745ce35be5975.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Layered: Baking, Building, and Styling Spectacular Cakes',
#   'Rating': 'One',
#   'Price': 'Â£40.11',
#   'Images': '../media/cache/98/d1/98d1c979c4bac9e147a6718946578b0f.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Judo: Seven Steps to Black Belt (an Introductory Guide for Beginners)',
#   'Rating': 'Two',
#   'Price': 'Â£53.90',
#   'Images': '../media/cache/5f/52/5f52b1bc6d45daab2e330c744feb0359.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Join',
#   'Rating': 'Five',
#   'Price': 'Â£35.67',
#   'Images': '../media/cache/93/63/9363f0065fbad5689f44fcf6e203eef3.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'In the Country We Love: My Family Divided',
#   'Rating': 'Four',
#   'Price': 'Â£22.00',
#   'Images': '../media/cache/fe/ea/feeafd2ad7b3077f8e74cbb1da9e3c7d.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Immunity: How Elie Metchnikoff Changed the Course of Modern Medicine',
#   'Rating': 'Five',
#   'Price': 'Â£57.36',
#   'Images': '../media/cache/26/1c/261c4eaf957ae4aacf2229b482e76dbe.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'I Hate Fairyland, Vol. 1: Madly Ever After (I Hate Fairyland (Compilations) #1-5)',
#   'Rating': 'Two',
#   'Price': 'Â£29.17',
#   'Images': '../media/cache/aa/74/aa74004807e97a79aa084b5db329a99b.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'I am a Hero Omnibus Volume 1',
#   'Rating': 'Three',
#   'Price': 'Â£54.63',
#   'Images': '../media/cache/16/d4/16d443437126bf6d536a89312c1995a5.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'How to Be Miserable: 40 Strategies You Already Use',
#   'Rating': 'One',
#   'Price': 'Â£46.03',
#   'Images': '../media/cache/da/8b/da8bc9b824dd3f446ef63e438ddbfc85.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Her Backup Boyfriend (The Sorensen Family #1)',
#   'Rating': 'One',
#   'Price': 'Â£33.97',
#   'Images': '../media/cache/1e/bb/1ebbbc3e2d3249b111033cfc40763b0b.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Giant Days, Vol. 2 (Giant Days #5-8)',
#   'Rating': 'Two',
#   'Price': 'Â£22.11',
#   'Images': '../media/cache/90/6f/906f0168b0e155a7077625499b1737b5.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Forever and Forever: The Courtship of Henry Longfellow and Fanny Appleton',
#   'Rating': 'Three',
#   'Price': 'Â£29.69',
#   'Images': '../media/cache/d6/58/d658a1485b130ff26ca5fb0d5975ed2e.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'First and First (Five Boroughs #3)',
#   'Rating': 'Four',
#   'Price': 'Â£15.97',
#   'Images': '../media/cache/c4/d1/c4d1517cc9370e292366b6132ca9ca36.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Fifty Shades Darker (Fifty Shades #2)',
#   'Rating': 'One',
#   'Price': 'Â£21.96',
#   'Images': '../media/cache/cc/bd/ccbdae9e29b3594301528fa2c876ec29.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Everydata: The Misinformation Hidden in the Little Data You Consume Every Day',
#   'Rating': 'Two',
#   'Price': 'Â£54.35',
#   'Images': '../media/cache/64/94/6494bf61176ca73b61255909230030be.jpg',
#   'Stock': 'In stock'},
#  {'Name': "Don't Be a Jerk: And Other Practical Advice from Dogen, Japan's Greatest Zen Master",
#   'Rating': 'Two',
#   'Price': 'Â£37.97',
#   'Images': '../media/cache/95/30/953013d044aa313cc162dec414f3969a.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Danganronpa Volume 1',
#   'Rating': 'Four',
#   'Price': 'Â£51.99',
#   'Images': '../media/cache/78/97/7897eea91c4a85aca58d925861d4afec.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Crown of Midnight (Throne of Glass #2)',
#   'Rating': 'Three',
#   'Price': 'Â£43.29',
#   'Images': '../media/cache/66/25/6625e3bbb050de3e42a0c302c0d69f1f.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Codename Baboushka, Volume 1: The Conclave of Death',
#   'Rating': 'Four',
#   'Price': 'Â£36.72',
#   'Images': '../media/cache/f6/88/f688a9d6a89fdf38e4e88439ee9eda69.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Camp Midnight',
#   'Rating': 'Four',
#   'Price': 'Â£17.08',
#   'Images': '../media/cache/dd/c9/ddc95df6754df8e71bf969c088056188.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Call the Nurse: True Stories of a Country Nurse on a Scottish Isle',
#   'Rating': 'Five',
#   'Price': 'Â£29.14',
#   'Images': '../media/cache/88/9e/889e0bac4c7c0e7178f0165b8d3b4617.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Burning',
#   'Rating': 'Three',
#   'Price': 'Â£28.81',
#   'Images': '../media/cache/26/95/269507c7bb35d2cec9b61a03d1c28e67.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Bossypants',
#   'Rating': 'Two',
#   'Price': 'Â£49.46',
#   'Images': '../media/cache/27/d2/27d20361745ec2f7be668b18a4da29da.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Bitch Planet, Vol. 1: Extraordinary Machine (Bitch Planet (Collected Editions))',
#   'Rating': 'Two',
#   'Price': 'Â£37.92',
#   'Images': '../media/cache/e4/1d/e41d34204a1fffbf825d8beb3dbf4cbc.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Avatar: The Last Airbender: Smoke and Shadow, Part 3 (Smoke and Shadow #3)',
#   'Rating': 'Two',
#   'Price': 'Â£28.09',
#   'Images': '../media/cache/06/18/061811c5845d0e13bc04b2a755f0830f.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Algorithms to Live By: The Computer Science of Human Decisions',
#   'Rating': 'One',
#   'Price': 'Â£30.81',
#   'Images': '../media/cache/23/b4/23b42e094c02d52b14b11a960d49610e.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'A World of Flavor: Your Gluten Free Passport',
#   'Rating': 'One',
#   'Price': 'Â£42.95',
#   'Images': '../media/cache/78/2e/782e315667ec50759b8603527ee33dec.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'A Piece of Sky, a Grain of Rice: A Memoir in Four Meditations',
#   'Rating': 'Five',
#   'Price': 'Â£56.76',
#   'Images': '../media/cache/08/89/088995e862aac86c88c608d763f6390e.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'A Murder in Time',
#   'Rating': 'One',
#   'Price': 'Â£16.64',
#   'Images': '../media/cache/11/aa/11aaad48b5f15e262456ca65294084da.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'A Flight of Arrows (The Pathfinders #2)',
#   'Rating': 'Five',
#   'Price': 'Â£55.53',
#   'Images': '../media/cache/82/96/8296f92b70fb1dafefecda92c1d51941.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'A Fierce and Subtle Poison',
#   'Rating': 'Four',
#   'Price': 'Â£28.13',
#   'Images': '../media/cache/12/f1/12f1963957f27fa83d51f76b183ef490.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'A Court of Thorns and Roses (A Court of Thorns and Roses #1)',
#   'Rating': 'One',
#   'Price': 'Â£52.37',
#   'Images': '../media/cache/c0/88/c08816960890396213a423941af65b8f.jpg',
#   'Stock': 'In stock'},
#  {'Name': '(Un)Qualified: How God Uses Broken People to Do Big Things',
#   'Rating': 'Five',
#   'Price': 'Â£54.00',
#   'Images': '../media/cache/cd/db/cddb3eb483ef11a088d519205b7098fb.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'You Are What You Love: The Spiritual Power of Habit',
#   'Rating': 'Four',
#   'Price': 'Â£21.87',
#   'Images': '../media/cache/6b/70/6b70f2cdb17d9ab7551240a88b9211fe.jpg',
#   'Stock': 'In stock'},
#  {'Name': "William Shakespeare's Star Wars: Verily, A New Hope (William Shakespeare's Star Wars #4)",
#   'Rating': 'Four',
#   'Price': 'Â£43.30',
#   'Images': '../media/cache/02/37/0237b445efc18c5562355a5a2c40889c.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Tuesday Nights in 1980',
#   'Rating': 'Two',
#   'Price': 'Â£21.04',
#   'Images': '../media/cache/6b/da/6bdae061cb92c32b0b83cda8dd10275d.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Tracing Numbers on a Train',
#   'Rating': 'Three',
#   'Price': 'Â£41.60',
#   'Images': '../media/cache/06/a6/06a6cfcf89afd1601cbba1a16cda57fb.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Throne of Glass (Throne of Glass #1)',
#   'Rating': 'Three',
#   'Price': 'Â£35.07',
#   'Images': '../media/cache/32/d6/32d6aa560e8ddf2a4da1526b95d4c7ab.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Thomas Jefferson and the Tripoli Pirates: The Forgotten War That Changed American History',
#   'Rating': 'One',
#   'Price': 'Â£59.64',
#   'Images': '../media/cache/97/47/974709d437b08e74649b5744471bf472.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Thirteen Reasons Why',
#   'Rating': 'One',
#   'Price': 'Â£52.72',
#   'Images': '../media/cache/8a/83/8a83b6ce350f01bab21f85e6ba539316.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'The White Cat and the Monk: A Retelling of the Poem â\x80\x9cPangur BÃ¡nâ\x80\x9d',
#   'Rating': 'Four',
#   'Price': 'Â£58.08',
#   'Images': '../media/cache/26/32/2632a1e12f2c085fabbe022ae4cd6933.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'The Wedding Dress',
#   'Rating': 'One',
#   'Price': 'Â£24.12',
#   'Images': '../media/cache/28/99/28992d89f4abf54fba183fc8d074adf3.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'The Vacationers',
#   'Rating': 'Four',
#   'Price': 'Â£42.15',
#   'Images': '../media/cache/37/25/372578cc073efae80cf284b56040a488.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'The Third Wave: An Entrepreneurâ\x80\x99s Vision of the Future',
#   'Rating': 'Five',
#   'Price': 'Â£12.61',
#   'Images': '../media/cache/d0/77/d077a30042df6b916bfc8d257345c69e.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'The Stranger',
#   'Rating': 'Four',
#   'Price': 'Â£17.44',
#   'Images': '../media/cache/ea/04/ea0476a6f4c318ceccf5e2f2b39f2b15.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'The Shadow Hero (The Shadow Hero)',
#   'Rating': 'One',
#   'Price': 'Â£33.14',
#   'Images': '../media/cache/1f/62/1f621dda1b302fc16d83d94b0b5ac31c.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'The Secret (The Secret #1)',
#   'Rating': 'Four',
#   'Price': 'Â£27.37',
#   'Images': '../media/cache/4e/0f/4e0f05ae01d8fb6bd0d3901edd06de16.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'The Regional Office Is Under Attack!',
#   'Rating': 'Five',
#   'Price': 'Â£51.36',
#   'Images': '../media/cache/f8/31/f8314c7fdaa79fb7191a583e9a852db8.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'The Psychopath Test: A Journey Through the Madness Industry',
#   'Rating': 'Two',
#   'Price': 'Â£36.00',
#   'Images': '../media/cache/34/f5/34f5f8e513c5f048241f5695e61b2483.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'The Project',
#   'Rating': 'One',
#   'Price': 'Â£10.65',
#   'Images': '../media/cache/10/6e/106e2fc7160712edf8e2ff996dc8cd6c.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'The Power of Now: A Guide to Spiritual Enlightenment',
#   'Rating': 'Two',
#   'Price': 'Â£43.54',
#   'Images': '../media/cache/03/38/0338682e76bad3216cd4c6c28b2b625a.jpg',
#   'Stock': 'In stock'},
#  {'Name': "The Omnivore's Dilemma: A Natural History of Four Meals",
#   'Rating': 'Two',
#   'Price': 'Â£38.21',
#   'Images': '../media/cache/14/f3/14f3d525e2a114cd71e27201a16af188.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'The Nerdy Nummies Cookbook: Sweet Treats for the Geek in All of Us',
#   'Rating': 'Five',
#   'Price': 'Â£37.34',
#   'Images': '../media/cache/61/bd/61bdfe3950643c47d70c37c4123530f3.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'The Murder of Roger Ackroyd (Hercule Poirot #4)',
#   'Rating': 'Four',
#   'Price': 'Â£44.10',
#   'Images': '../media/cache/29/fe/29fe70b1b2e5a9ba61d4bd331255e19e.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'The Mistake (Off-Campus #2)',
#   'Rating': 'Three',
#   'Price': 'Â£43.29',
#   'Images': '../media/cache/a5/43/a543b100a8c1861c1bf5374ca6b576fe.jpg',
#   'Stock': 'In stock'},
#  {'Name': "The Matchmaker's Playbook (Wingmen Inc. #1)",
#   'Rating': 'One',
#   'Price': 'Â£55.85',
#   'Images': '../media/cache/84/ac/84acb0606c96e55dc729a9d6572a08fb.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'The Love and Lemons Cookbook: An Apple-to-Zucchini Celebration of Impromptu Cooking',
#   'Rating': 'Two',
#   'Price': 'Â£37.60',
#   'Images': '../media/cache/0d/1f/0d1f3f934460f5a50aaa8c366641234c.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'The Long Shadow of Small Ghosts: Murder and Memory in an American City',
#   'Rating': 'One',
#   'Price': 'Â£10.97',
#   'Images': '../media/cache/f2/e5/f2e51dd2b26600459f8eaeb6b9eecaa7.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'The Kite Runner',
#   'Rating': 'Four',
#   'Price': 'Â£41.82',
#   'Images': '../media/cache/58/9d/589d73503d9a23d224de836134fae553.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'The House by the Lake',
#   'Rating': 'One',
#   'Price': 'Â£36.95',
#   'Images': '../media/cache/0d/cb/0dcb33d60b0e79adf8ab9842e697ea2e.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'The Glittering Court (The Glittering Court #1)',
#   'Rating': 'One',
#   'Price': 'Â£44.28',
#   'Images': '../media/cache/3e/0b/3e0b16851bec08b6cbf78d5f64af9114.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'The Girl on the Train',
#   'Rating': 'Two',
#   'Price': 'Â£55.02',
#   'Images': '../media/cache/25/6c/256c946dd0962095f66c6de3b15ab300.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'The Genius of Birds',
#   'Rating': 'One',
#   'Price': 'Â£17.24',
#   'Images': '../media/cache/13/57/1357c6aa40c9e63d2f931927fbf81f3f.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'The Emerald Mystery',
#   'Rating': 'Two',
#   'Price': 'Â£23.15',
#   'Images': '../media/cache/81/58/81586cd0bf8743e1f5ed80b6a0e1fabe.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'The Cookies & Cups Cookbook: 125+ sweet & savory recipes reminding you to Always Eat Dessert First',
#   'Rating': 'One',
#   'Price': 'Â£41.25',
#   'Images': '../media/cache/54/89/54899b4584e941ceced511d81092c88a.jpg',
#   'Stock': 'In stock'},
#  {'Name': "The Bridge to Consciousness: I'm Writing the Bridge Between Science and Our Old and New Beliefs.",
#   'Rating': 'Three',
#   'Price': 'Â£32.00',
#   'Images': '../media/cache/fe/b7/feb764b2afa54991cfdbbffdf501b333.jpg',
#   'Stock': 'In stock'},
#  {'Name': "The Artist's Way: A Spiritual Path to Higher Creativity",
#   'Rating': 'Five',
#   'Price': 'Â£38.49',
#   'Images': '../media/cache/0e/6d/0e6dc2484322c5b9e7854ced66fdf62d.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'The Art of War',
#   'Rating': 'Five',
#   'Price': 'Â£33.34',
#   'Images': '../media/cache/6d/71/6d71e36c8b1b9c885e1bb6c72cd8bcf8.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'The Argonauts',
#   'Rating': 'Two',
#   'Price': 'Â£10.93',
#   'Images': '../media/cache/0a/15/0a1567cd04a6582d333db71337b4e2a6.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'The 10% Entrepreneur: Live Your Startup Dream Without Quitting Your Day Job',
#   'Rating': 'Three',
#   'Price': 'Â£27.55',
#   'Images': '../media/cache/82/93/82939ca78da0b724f16ec814849514fd.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Suddenly in Love (Lake Haven #1)',
#   'Rating': 'Two',
#   'Price': 'Â£55.99',
#   'Images': '../media/cache/e9/f4/e9f4bc8cf5ffaea1504623c936e90a48.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Something More Than This',
#   'Rating': 'Four',
#   'Price': 'Â£16.24',
#   'Images': '../media/cache/59/10/5910fbd8a95e8e9de9c660b71e0694e2.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Soft Apocalypse',
#   'Rating': 'Two',
#   'Price': 'Â£26.12',
#   'Images': '../media/cache/f0/06/f0060c756556b855184fa32f66280961.jpg',
#   'Stock': 'In stock'},
#  {'Name': "So You've Been Publicly Shamed",
#   'Rating': 'Two',
#   'Price': 'Â£12.23',
#   'Images': '../media/cache/6e/d4/6ed4991d97f60db29ec7b421e61a2cf3.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Shoe Dog: A Memoir by the Creator of NIKE',
#   'Rating': 'Two',
#   'Price': 'Â£23.99',
#   'Images': '../media/cache/19/aa/19aa1184a3565b1dae6092146018e109.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Shobu Samurai, Project Aryoku (#3)',
#   'Rating': 'Three',
#   'Price': 'Â£29.06',
#   'Images': '../media/cache/ae/0c/ae0ccc307568b6d7699786411f3cbcc4.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Secrets and Lace (Fatal Hearts #1)',
#   'Rating': 'One',
#   'Price': 'Â£20.27',
#   'Images': '../media/cache/84/7c/847c06b541e2a3b2228b96d97a5fe7a6.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Scarlett Epstein Hates It Here',
#   'Rating': 'Five',
#   'Price': 'Â£43.55',
#   'Images': '../media/cache/0f/d3/0fd306891f8fd3196653022fd67d6c87.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Romero and Juliet: A Tragic Tale of Love and Zombies',
#   'Rating': 'One',
#   'Price': 'Â£36.94',
#   'Images': '../media/cache/12/f8/12f8002e5aab6d783e29b31aad36b5ba.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Redeeming Love',
#   'Rating': 'Five',
#   'Price': 'Â£20.47',
#   'Images': '../media/cache/21/21/2121ba78e26194d92c334fde3850f840.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Poses for Artists Volume 1 - Dynamic and Sitting Poses: An Essential Reference for Figure Drawing and the Human Form',
#   'Rating': 'One',
#   'Price': 'Â£41.06',
#   'Images': '../media/cache/5a/89/5a89e2dd7866dda6660fe508bc4b5249.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Poems That Make Grown Women Cry',
#   'Rating': 'Four',
#   'Price': 'Â£14.19',
#   'Images': '../media/cache/38/64/386468a8c3e6b880664bf7885bf6f726.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Nightingale, Sing',
#   'Rating': 'One',
#   'Price': 'Â£38.28',
#   'Images': '../media/cache/18/08/18086e581ad354aa65f945c2b5c51350.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Night Sky with Exit Wounds',
#   'Rating': 'One',
#   'Price': 'Â£41.05',
#   'Images': '../media/cache/25/54/2554431c797ec725eea50b3f8a83758c.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Mrs. Houdini',
#   'Rating': 'Five',
#   'Price': 'Â£30.25',
#   'Images': '../media/cache/0e/fe/0efe86960cdff718aed01a5c3f65b1c3.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Modern Romance',
#   'Rating': 'Five',
#   'Price': 'Â£28.26',
#   'Images': '../media/cache/28/78/2878538a1039d9c4649110499a1393fb.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Miss Peregrineâ\x80\x99s Home for Peculiar Children (Miss Peregrineâ\x80\x99s Peculiar Children #1)',
#   'Rating': 'One',
#   'Price': 'Â£10.76',
#   'Images': '../media/cache/01/26/01264865c12ed6d987d6f0858cd1d0ba.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Louisa: The Extraordinary Life of Mrs. Adams',
#   'Rating': 'Two',
#   'Price': 'Â£16.85',
#   'Images': '../media/cache/6f/d9/6fd92e5143cbd5bb8bcf034e5f007dde.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Little Red',
#   'Rating': 'Three',
#   'Price': 'Â£13.47',
#   'Images': '../media/cache/80/25/8025b80a40178f2a6dd4f99ad88e0fba.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Library of Souls (Miss Peregrineâ\x80\x99s Peculiar Children #3)',
#   'Rating': 'Five',
#   'Price': 'Â£48.56',
#   'Images': '../media/cache/f8/54/f85417465a73e33604624205ba8306cc.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Large Print Heart of the Pride',
#   'Rating': 'Two',
#   'Price': 'Â£19.15',
#   'Images': '../media/cache/bd/e9/bde95ab9f776c911a7aa759cad60bb41.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'I Had a Nice Time And Other Lies...: How to find love & sh*t like that',
#   'Rating': 'Four',
#   'Price': 'Â£57.36',
#   'Images': '../media/cache/5f/72/5f72c8a0d5a7292e2929a354ec8a022f.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Hollow City (Miss Peregrineâ\x80\x99s Peculiar Children #2)',
#   'Rating': 'One',
#   'Price': 'Â£42.98',
#   'Images': '../media/cache/e2/60/e260b008b7ea7970562295b7bc64b0cb.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Grumbles',
#   'Rating': 'Two',
#   'Price': 'Â£22.16',
#   'Images': '../media/cache/d6/1b/d61b12ef0e69d49e2645537dd6a8472a.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Full Moon over Noahâ\x80\x99s Ark: An Odyssey to Mount Ararat and Beyond',
#   'Rating': 'Four',
#   'Price': 'Â£49.43',
#   'Images': '../media/cache/57/77/57770cac1628f4407636635f4b85e88c.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Frostbite (Vampire Academy #2)',
#   'Rating': 'Five',
#   'Price': 'Â£29.99',
#   'Images': '../media/cache/71/76/7176317f1915fa0658bb2fe400441207.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Follow You Home',
#   'Rating': 'One',
#   'Price': 'Â£21.36',
#   'Images': '../media/cache/a7/4b/a74b35375ce874153fd352e33bc7bac9.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'First Steps for New Christians (Print Edition)',
#   'Rating': 'One',
#   'Price': 'Â£29.00',
#   'Images': '../media/cache/f1/73/f1731459b1e2f4becf2c52b8f30b8cd7.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Finders Keepers (Bill Hodges Trilogy #2)',
#   'Rating': 'Five',
#   'Price': 'Â£53.53',
#   'Images': '../media/cache/6a/81/6a81103b1c01a3f6c56e5718a838a4c8.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Fables, Vol. 1: Legends in Exile (Fables #1)',
#   'Rating': 'Four',
#   'Price': 'Â£41.62',
#   'Images': '../media/cache/51/8c/518c184a793b751b43045637c8002eb7.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Eureka Trivia 6.0',
#   'Rating': 'Four',
#   'Price': 'Â£54.59',
#   'Images': '../media/cache/96/17/96173470df6fc6fef4d0008e957653ce.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Drive: The Surprising Truth About What Motivates Us',
#   'Rating': 'Four',
#   'Price': 'Â£34.95',
#   'Images': '../media/cache/8a/49/8a490347afdc10abe7c2099e466de32f.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Done Rubbed Out (Reightman & Bailey #1)',
#   'Rating': 'Five',
#   'Price': 'Â£37.72',
#   'Images': '../media/cache/08/4d/084da0199a717cb6c1eda30f98d0ea4c.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Doing It Over (Most Likely To #1)',
#   'Rating': 'Three',
#   'Price': 'Â£35.61',
#   'Images': '../media/cache/e9/25/e9250495a525eb203652ad9da85ccb8e.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Deliciously Ella Every Day: Quick and Easy Recipes for Gluten-Free Snacks, Packed Lunches, and Simple Meals',
#   'Rating': 'Three',
#   'Price': 'Â£42.16',
#   'Images': '../media/cache/20/f2/20f28657b49f8cb24ed2ec6448bb6df3.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Dark Notes',
#   'Rating': 'Five',
#   'Price': 'Â£19.19',
#   'Images': '../media/cache/6e/4e/6e4e8f4f4abd94356a9be840e4681e65.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Daring Greatly: How the Courage to Be Vulnerable Transforms the Way We Live, Love, Parent, and Lead',
#   'Rating': 'Three',
#   'Price': 'Â£19.43',
#   'Images': '../media/cache/55/ce/55ced903becc59121d6edb47a4dcfb56.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Close to You',
#   'Rating': 'Four',
#   'Price': 'Â£49.46',
#   'Images': '../media/cache/fa/f6/faf6d69a42f477e1da80a71f05a4dc25.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Chasing Heaven: What Dying Taught Me About Living',
#   'Rating': 'Two',
#   'Price': 'Â£37.80',
#   'Images': '../media/cache/b7/6a/b76a73640d26b09c4a6f373b09050bed.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Big Magic: Creative Living Beyond Fear',
#   'Rating': 'Three',
#   'Price': 'Â£30.80',
#   'Images': '../media/cache/62/ad/62ad9b4077416ddc0c4908062bca0e5e.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Becoming Wise: An Inquiry into the Mystery and Art of Living',
#   'Rating': 'Two',
#   'Price': 'Â£27.43',
#   'Images': '../media/cache/ff/69/ff69c96b05affa03f647287e46210bf9.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Beauty Restored (Riley Family Legacy Novellas #3)',
#   'Rating': 'Two',
#   'Price': 'Â£11.11',
#   'Images': '../media/cache/51/6f/516f605a957a1f5592b81f4e06c491bb.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Batman: The Long Halloween (Batman)',
#   'Rating': 'Two',
#   'Price': 'Â£36.50',
#   'Images': '../media/cache/78/a7/78a7f184a4d6d62412861c68f1c3ad90.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Batman: The Dark Knight Returns (Batman)',
#   'Rating': 'Five',
#   'Price': 'Â£15.38',
#   'Images': '../media/cache/be/a9/bea95dbd7b2a843519c9a1dcfc433f9b.jpg',
#   'Stock': 'In stock'},
#  {'Name': "Ayumi's Violin",
#   'Rating': 'Two',
#   'Price': 'Â£15.48',
#   'Images': '../media/cache/fa/18/fa18c44fba20b8191f6a88e2e28092fd.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Anonymous',
#   'Rating': 'Four',
#   'Price': 'Â£46.82',
#   'Images': '../media/cache/fb/75/fb75a0ce3e0b01fa3852806c6d1f1af6.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Amy Meets the Saints and Sages',
#   'Rating': 'Three',
#   'Price': 'Â£18.46',
#   'Images': '../media/cache/00/53/0053efa8515b8e2ad9b029c298766e9f.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Amid the Chaos',
#   'Rating': 'One',
#   'Price': 'Â£36.58',
#   'Images': '../media/cache/52/46/524655fade1d9fe1475395a3eaff827a.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Amatus',
#   'Rating': 'Five',
#   'Price': 'Â£50.54',
#   'Images': '../media/cache/8f/92/8f92c3b5dc8f5c1a23324bda7477b19c.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Agnostic: A Spirited Manifesto',
#   'Rating': 'Five',
#   'Price': 'Â£12.51',
#   'Images': '../media/cache/9f/fc/9ffc43826233092d2acb4414f86627eb.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Zealot: The Life and Times of Jesus of Nazareth',
#   'Rating': 'Three',
#   'Price': 'Â£24.70',
#   'Images': '../media/cache/3d/60/3d6003fc37b842a07c2dbe28e47448e1.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'You (You #1)',
#   'Rating': 'Five',
#   'Price': 'Â£43.61',
#   'Images': '../media/cache/d6/97/d697268540fa982f4dce39f61ed3a342.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Wonder Woman: Earth One, Volume One (Wonder Woman: Earth One #1)',
#   'Rating': 'Four',
#   'Price': 'Â£37.34',
#   'Images': '../media/cache/19/39/19396172462f4cc0504d4e6e8b0e1647.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Wild Swans',
#   'Rating': 'Two',
#   'Price': 'Â£14.36',
#   'Images': '../media/cache/bb/72/bb723ad463531c602ad8bcb244253bf3.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Why the Right Went Wrong: Conservatism--From Goldwater to the Tea Party and Beyond',
#   'Rating': 'Four',
#   'Price': 'Â£52.65',
#   'Images': '../media/cache/db/1b/db1babd3c09b84da800b0e9897fe0097.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Whole Lotta Creativity Going On: 60 Fun and Unusual Exercises to Awaken and Strengthen Your Creativity',
#   'Rating': 'Four',
#   'Price': 'Â£38.20',
#   'Images': '../media/cache/ba/36/ba368dfb2b6ae9979ff59d049c626167.jpg',
#   'Stock': 'In stock'},
#  {'Name': "What's It Like in Space?: Stories from Astronauts Who've Been There",
#   'Rating': 'Two',
#   'Price': 'Â£19.60',
#   'Images': '../media/cache/43/b7/43b70859e93901b019791cef86539ffc.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'We Are Robin, Vol. 1: The Vigilante Business (We Are Robin #1)',
#   'Rating': 'One',
#   'Price': 'Â£53.90',
#   'Images': '../media/cache/66/d6/66d6d2b4c0acfa8f40ad0285186ed2d8.jpg',
#   'Stock': 'In stock'},
#  {'Name': "Walt Disney's Alice in Wonderland",
#   'Rating': 'Five',
#   'Price': 'Â£12.96',
#   'Images': '../media/cache/28/50/2850439c2ba103fb69dba9cd2dd9f0c2.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'V for Vendetta (V for Vendetta Complete)',
#   'Rating': 'Four',
#   'Price': 'Â£37.10',
#   'Images': '../media/cache/cc/8f/cc8fb914bfee31a7903a5cabaae64796.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Until Friday Night (The Field Party #1)',
#   'Rating': 'Two',
#   'Price': 'Â£46.31',
#   'Images': '../media/cache/19/cf/19cf50aea5bf0e8f4bc016f3745b3dfe.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Unbroken: A World War II Story of Survival, Resilience, and Redemption',
#   'Rating': 'Two',
#   'Price': 'Â£45.95',
#   'Images': '../media/cache/74/cd/74cd3f345b50452c3be6631669f13aa8.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Twenty Yawns',
#   'Rating': 'Two',
#   'Price': 'Â£22.08',
#   'Images': '../media/cache/2b/38/2b380f77723c797c0389f978afa6db58.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Through the Woods',
#   'Rating': 'Two',
#   'Price': 'Â£25.38',
#   'Images': '../media/cache/4c/af/4caf8f2a5ee8828d408cc8faadd3419c.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'This Is Where It Ends',
#   'Rating': 'Two',
#   'Price': 'Â£27.12',
#   'Images': '../media/cache/18/0b/180bfe1902cb3c0eb77d7c712efa2a96.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'The Year of Magical Thinking',
#   'Rating': 'Two',
#   'Price': 'Â£43.04',
#   'Images': '../media/cache/bf/e5/bfe526c22c7c08235c27a6474ebb4db9.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'The Wright Brothers',
#   'Rating': 'Four',
#   'Price': 'Â£56.80',
#   'Images': '../media/cache/02/2e/022e8b81ba1405991401bb46d6330c73.jpg',
#   'Stock': 'In stock'},
#  {'Name': "The White Queen (The Cousins' War #1)",
#   'Rating': 'Five',
#   'Price': 'Â£25.91',
#   'Images': '../media/cache/72/d8/72d861617b6d3aababe6e61e8d3c1056.jpg',
#   'Stock': 'In stock'},
#  {'Name': "The Wedding Pact (The O'Malleys #2)",
#   'Rating': 'Three',
#   'Price': 'Â£32.61',
#   'Images': '../media/cache/7e/67/7e67addd80caaf8a9f9e9daa9cf66bb2.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'The Time Keeper',
#   'Rating': 'Five',
#   'Price': 'Â£27.88',
#   'Images': '../media/cache/8f/f8/8ff8680dde59ea739d6978a01e4d7fe5.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'The Testament of Mary',
#   'Rating': 'Four',
#   'Price': 'Â£52.67',
#   'Images': '../media/cache/83/05/8305154438c91a02cefacf4ec8b53393.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'The Star-Touched Queen',
#   'Rating': 'Five',
#   'Price': 'Â£46.02',
#   'Images': '../media/cache/53/5e/535e2be0b423797c2cdc7d98882c820a.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'The Songs of the Gods',
#   'Rating': 'Five',
#   'Price': 'Â£44.48',
#   'Images': '../media/cache/6c/a3/6ca34db7c01e554ad17bd3be74b561e3.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'The Song of Achilles',
#   'Rating': 'Five',
#   'Price': 'Â£37.40',
#   'Images': '../media/cache/66/f7/66f79b76d6c6b64fcc8110515c454e09.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'The Rosie Project (Don Tillman #1)',
#   'Rating': 'One',
#   'Price': 'Â£54.04',
#   'Images': '../media/cache/f0/db/f0db1cf76d45f0522d4c8c3c39aa0dd8.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'The Power of Habit: Why We Do What We Do in Life and Business',
#   'Rating': 'Three',
#   'Price': 'Â£16.88',
#   'Images': '../media/cache/52/df/52dfc44f48cf29e7a9e305bcb63e1899.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'The Marriage of Opposites',
#   'Rating': 'Four',
#   'Price': 'Â£28.08',
#   'Images': '../media/cache/0f/c2/0fc21ec3489cb23116778ee84f425eca.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'The Lucifer Effect: Understanding How Good People Turn Evil',
#   'Rating': 'One',
#   'Price': 'Â£10.40',
#   'Images': '../media/cache/a6/c8/a6c8256b123493472591c5855c7de704.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'The Long Haul (Diary of a Wimpy Kid #9)',
#   'Rating': 'One',
#   'Price': 'Â£44.07',
#   'Images': '../media/cache/46/bd/46bdee520b8136972262fd040533772d.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'The Loney',
#   'Rating': 'One',
#   'Price': 'Â£23.40',
#   'Images': '../media/cache/6d/10/6d10387a0175701d4ff456a0c7eee67b.jpg',
# ...
#   'Rating': 'One',
#   'Price': 'Â£36.58',
#   'Images': '../media/cache/44/ff/44ff81a2ea37d3946605e205ddd538eb.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Crazy Love: Overwhelmed by a Relentless God',
#   'Rating': 'Two',
#   'Price': 'Â£47.72',
#   'Images': '../media/cache/03/f1/03f1e337afadba35687672b5625a9757.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Cometh the Hour (The Clifton Chronicles #6)',
#   'Rating': 'Three',
#   'Price': 'Â£25.01',
#   'Images': '../media/cache/55/11/5511a4296fbd484dcaa89c8a2d25965d.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Code Name Verity (Code Name Verity #1)',
#   'Rating': 'Four',
#   'Price': 'Â£22.13',
#   'Images': '../media/cache/f5/58/f55886d1bf600529a35e1bd932c78ca0.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Clockwork Angel (The Infernal Devices #1)',
#   'Rating': 'One',
#   'Price': 'Â£44.14',
#   'Images': '../media/cache/ff/0e/ff0ee0002f510112b6d7a88f53366e1d.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'City of Glass (The Mortal Instruments #3)',
#   'Rating': 'Four',
#   'Price': 'Â£56.02',
#   'Images': '../media/cache/00/08/0008e65aa431ed3625ad3a4352f8e90d.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'City of Fallen Angels (The Mortal Instruments #4)',
#   'Rating': 'Four',
#   'Price': 'Â£11.23',
#   'Images': '../media/cache/c9/40/c940b6c329ecc39aaed2ab0140592a4b.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'City of Bones (The Mortal Instruments #1)',
#   'Rating': 'One',
#   'Price': 'Â£43.28',
#   'Images': '../media/cache/96/af/96af4aaf25ab49b057c10b5b7eb7652c.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'City of Ashes (The Mortal Instruments #2)',
#   'Rating': 'One',
#   'Price': 'Â£47.27',
#   'Images': '../media/cache/68/da/68dab382d535305ca6025be9921df0d1.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Cell',
#   'Rating': 'Four',
#   'Price': 'Â£20.29',
#   'Images': '../media/cache/0b/97/0b97282ed82b771ed328e05386a84adb.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Catching Jordan (Hundred Oaks)',
#   'Rating': 'Three',
#   'Price': 'Â£50.83',
#   'Images': '../media/cache/ad/ac/adac97366586d261feab30bf5220756e.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Carry On, Warrior: Thoughts on Life Unarmed',
#   'Rating': 'Three',
#   'Price': 'Â£31.85',
#   'Images': '../media/cache/dd/f5/ddf5da673bb34a74a81faf7271c7ca13.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Carrie',
#   'Rating': 'Two',
#   'Price': 'Â£46.23',
#   'Images': '../media/cache/c5/6f/c56f37eb53888765eb55f86fb7381c2f.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Buying In: The Secret Dialogue Between What We Buy and Who We Are',
#   'Rating': 'Four',
#   'Price': 'Â£37.80',
#   'Images': '../media/cache/f2/fa/f2faa289117546efa0b4068a07778ab0.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Brain on Fire: My Month of Madness',
#   'Rating': 'Five',
#   'Price': 'Â£49.32',
#   'Images': '../media/cache/88/aa/88aad1204951e0900906173b086e6695.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Batman: Europa',
#   'Rating': 'Two',
#   'Price': 'Â£32.01',
#   'Images': '../media/cache/f1/fe/f1fecf0ce9b5771e4d2c9619e8550988.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Barefoot Contessa Back to Basics',
#   'Rating': 'One',
#   'Price': 'Â£28.01',
#   'Images': '../media/cache/b8/38/b838b65e0e1ac3a9b498dfb1bf004420.jpg',
#   'Stock': 'In stock'},
#  {'Name': "Barefoot Contessa at Home: Everyday Recipes You'll Make Over and Over Again",
#   'Rating': 'Five',
#   'Price': 'Â£50.62',
#   'Images': '../media/cache/74/aa/74aa29b1ba4147eaf5b46671bf235861.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Balloon Animals',
#   'Rating': 'Three',
#   'Price': 'Â£17.03',
#   'Images': '../media/cache/6e/23/6e2324cae6335e8e98c8b46597afc9a3.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Art Ops Vol. 1',
#   'Rating': 'Three',
#   'Price': 'Â£48.80',
#   'Images': '../media/cache/0b/b4/0bb4c64f1522c033368df5567a349472.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Aristotle and Dante Discover the Secrets of the Universe (Aristotle and Dante Discover the Secrets of the Universe #1)',
#   'Rating': 'Four',
#   'Price': 'Â£58.14',
#   'Images': '../media/cache/61/1a/611aba0ef5b859ba1977ef30677b0194.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Angels Walking (Angels Walking #1)',
#   'Rating': 'Two',
#   'Price': 'Â£34.20',
#   'Images': '../media/cache/50/0e/500eeb810e940424827580574e46852c.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Angels & Demons (Robert Langdon #1)',
#   'Rating': 'Three',
#   'Price': 'Â£51.48',
#   'Images': '../media/cache/b4/2a/b42a187c37de904f776070c57f51c756.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'All the Light We Cannot See',
#   'Rating': 'Five',
#   'Price': 'Â£29.87',
#   'Images': '../media/cache/41/c3/41c37f7f0e03ee1144dd6fa89483b5d9.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Adulthood Is a Myth: A "Sarah\'s Scribbles" Collection',
#   'Rating': 'Two',
#   'Price': 'Â£10.90',
#   'Images': '../media/cache/a2/b9/a2b974e5a66e7502c77d2e4632abe033.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Abstract City',
#   'Rating': 'Five',
#   'Price': 'Â£56.37',
#   'Images': '../media/cache/e7/70/e77019ebd71bcf6badb085bddf47c413.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'A Time of Torment (Charlie Parker #14)',
#   'Rating': 'Five',
#   'Price': 'Â£48.35',
#   'Images': '../media/cache/e8/c0/e8c0ba15066bab950ae161fd60949b9a.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'A Study in Scarlet (Sherlock Holmes #1)',
#   'Rating': 'Two',
#   'Price': 'Â£16.73',
#   'Images': '../media/cache/8f/a4/8fa41d6caa10e427356b8a590eb4d96b.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'A Series of Catastrophes and Miracles: A True Story of Love, Science, and Cancer',
#   'Rating': 'Two',
#   'Price': 'Â£56.48',
#   'Images': '../media/cache/9b/20/9b2076ce7414103a093ce2459d089969.jpg',
#   'Stock': 'In stock'},
#  {'Name': "A People's History of the United States",
#   'Rating': 'Two',
#   'Price': 'Â£40.79',
#   'Images': '../media/cache/75/20/75200336c141156746000f7055df344a.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'A Man Called Ove',
#   'Rating': 'One',
#   'Price': 'Â£39.72',
#   'Images': '../media/cache/9c/f1/9cf1f4a47b8d08909fc092e6ae598d83.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'A Distant Mirror: The Calamitous 14th Century',
#   'Rating': 'Three',
#   'Price': 'Â£14.58',
#   'Images': '../media/cache/41/d5/41d5fa6a81cdbcbe6b0b15757a4c9144.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'A Brush of Wings (Angels Walking #3)',
#   'Rating': 'One',
#   'Price': 'Â£55.51',
#   'Images': '../media/cache/4d/16/4d163d43cb4aa624e599330a39abace5.jpg',
#   'Stock': 'In stock'},
#  {'Name': '1491: New Revelations of the Americas Before Columbus',
#   'Rating': 'Three',
#   'Price': 'Â£21.80',
#   'Images': '../media/cache/88/75/8875f384ce9103281b7f6e86a2b8204d.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'The Three Searches, Meaning, and the Story',
#   'Rating': 'Three',
#   'Price': 'Â£13.33',
#   'Images': '../media/cache/83/35/8335b71599b5a257a56cfabdd79080a4.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Searching for Meaning in Gailana',
#   'Rating': 'One',
#   'Price': 'Â£38.73',
#   'Images': '../media/cache/3b/04/3b045fe0394dc192950a0ec9e3812fe4.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Rook',
#   'Rating': 'Four',
#   'Price': 'Â£37.86',
#   'Images': '../media/cache/55/33/5533595a623c3bb947c4a5171fc2df08.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'My Kitchen Year: 136 Recipes That Saved My Life',
#   'Rating': 'Two',
#   'Price': 'Â£11.53',
#   'Images': '../media/cache/76/a1/76a1516c8d9c3e620626f30840013a85.jpg',
#   'Stock': 'In stock'},
#  {'Name': '13 Hours: The Inside Account of What Really Happened In Benghazi',
#   'Rating': 'One',
#   'Price': 'Â£27.06',
#   'Images': '../media/cache/15/f7/15f78e0b04feb9b94e88865803cb5e9e.jpg',
#   'Stock': 'In stock'},
#  {'Name': "Will You Won't You Want Me?",
#   'Rating': 'Three',
#   'Price': 'Â£13.86',
#   'Images': '../media/cache/16/e3/16e3ca741956485119251e7442a67e2e.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Tipping Point for Planet Earth: How Close Are We to the Edge?',
#   'Rating': 'One',
#   'Price': 'Â£37.55',
#   'Images': '../media/cache/56/97/5697f2f8f628129df01c5790985ffd9b.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'The Star-Touched Queen',
#   'Rating': 'Five',
#   'Price': 'Â£32.30',
#   'Images': '../media/cache/d3/0d/d30dd8b6be6f9fcfd17178e8083238b6.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'The Silent Sister (Riley MacPherson #1)',
#   'Rating': 'Five',
#   'Price': 'Â£46.29',
#   'Images': '../media/cache/30/2c/302cd9c84442e139145ec0993880d7e0.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'The Midnight Watch: A Novel of the Titanic and the Californian',
#   'Rating': 'One',
#   'Price': 'Â£26.20',
#   'Images': '../media/cache/97/3a/973a2c3462a18fc90d3b9662d959df37.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'The Lonely City: Adventures in the Art of Being Alone',
#   'Rating': 'Two',
#   'Price': 'Â£33.26',
#   'Images': '../media/cache/5c/5e/5c5e527fea6b17199773bb175b515aee.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'The Gray Rhino: How to Recognize and Act on the Obvious Dangers We Ignore',
#   'Rating': 'Four',
#   'Price': 'Â£59.15',
#   'Images': '../media/cache/9f/25/9f255826f354776dda9afbd5576a7add.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'The Golden Condom: And Other Essays on Love Lost and Found',
#   'Rating': 'One',
#   'Price': 'Â£39.43',
#   'Images': '../media/cache/dc/4d/dc4d070e33813a07a4e02f069e6d482f.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'The Epidemic (The Program 0.6)',
#   'Rating': 'Five',
#   'Price': 'Â£14.44',
#   'Images': '../media/cache/87/cd/87cd652c35e2a78535c83becae33cff2.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'The Dinner Party',
#   'Rating': 'Two',
#   'Price': 'Â£56.54',
#   'Images': '../media/cache/ba/76/ba761d23c5c0e5a0638e04739c69c5d0.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'The Diary of a Young Girl',
#   'Rating': 'Three',
#   'Price': 'Â£59.90',
#   'Images': '../media/cache/83/d5/83d5526864a108d27fd4b03dd31ec18b.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'The Children',
#   'Rating': 'Three',
#   'Price': 'Â£11.88',
#   'Images': '../media/cache/d8/03/d803ab341d3020a3bb280d6135e4ae65.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Stars Above (The Lunar Chronicles #4.5)',
#   'Rating': 'Two',
#   'Price': 'Â£48.05',
#   'Images': '../media/cache/fd/5b/fd5b14399052ab552e240ed18ab03c6d.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Snatched: How A Drug Queen Went Undercover for the DEA and Was Kidnapped By Colombian Guerillas',
#   'Rating': 'Three',
#   'Price': 'Â£21.21',
#   'Images': '../media/cache/2a/f3/2af39796852729270fb23e05a662a42c.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Raspberry Pi Electronics Projects for the Evil Genius',
#   'Rating': 'Four',
#   'Price': 'Â£49.67',
#   'Images': '../media/cache/a2/da/a2da8957b9cb8265d7f1dfeb0651f1c7.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Quench Your Own Thirst: Business Lessons Learned Over a Beer or Two',
#   'Rating': 'One',
#   'Price': 'Â£43.14',
#   'Images': '../media/cache/2d/fd/2dfdc52bcdbd82dee50372bc46c83e15.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Psycho: Sanitarium (Psycho #1.5)',
#   'Rating': 'Five',
#   'Price': 'Â£36.97',
#   'Images': '../media/cache/02/5c/025c30a378e2a4190e84f1429e81b803.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Poisonous (Max Revere Novels #3)',
#   'Rating': 'Three',
#   'Price': 'Â£26.80',
#   'Images': '../media/cache/23/52/2352718971d5e166fa9541a5a7d716fa.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'One with You (Crossfire #5)',
#   'Rating': 'Four',
#   'Price': 'Â£15.71',
#   'Images': '../media/cache/b8/29/b829181ae95c8f020c1ad3273192de30.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'No Love Allowed (Dodge Cove #1)',
#   'Rating': 'Four',
#   'Price': 'Â£54.65',
#   'Images': '../media/cache/70/3e/703e053877204a396ec6e7beac863118.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Murder at the 42nd Street Library (Raymond Ambler #1)',
#   'Rating': 'Four',
#   'Price': 'Â£54.36',
#   'Images': '../media/cache/c3/8d/c38d65cd155b67ca025f0655bd1bb095.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Most Wanted',
#   'Rating': 'Three',
#   'Price': 'Â£35.28',
#   'Images': '../media/cache/8b/bc/8bbc5ab4c3784b4d9b93eb0fd1fb6fd6.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Love, Lies and Spies',
#   'Rating': 'Two',
#   'Price': 'Â£20.55',
#   'Images': '../media/cache/7a/22/7a224a6e174af91950e9b124afe54e0e.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'How to Speak Golf: An Illustrated Guide to Links Lingo',
#   'Rating': 'Five',
#   'Price': 'Â£58.32',
#   'Images': '../media/cache/d2/64/d264ad1af882ce391005dc7215ac90e7.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Hide Away (Eve Duncan #20)',
#   'Rating': 'One',
#   'Price': 'Â£11.84',
#   'Images': '../media/cache/57/07/5707c3d5d4fd44d943d51730ba7d429a.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Furiously Happy: A Funny Book About Horrible Things',
#   'Rating': 'Four',
#   'Price': 'Â£41.46',
#   'Images': '../media/cache/ab/2a/ab2ae4f02aa46271b4bfc77494039fc6.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Everyday Italian: 125 Simple and Delicious Recipes',
#   'Rating': 'Five',
#   'Price': 'Â£20.10',
#   'Images': '../media/cache/5a/64/5a6499d41ccaad4c4f7eeaa90e16345a.jpg',
#   'Stock': 'In stock'},
#  {'Name': "Equal Is Unfair: America's Misguided Fight Against Income Inequality",
#   'Rating': 'One',
#   'Price': 'Â£56.86',
#   'Images': '../media/cache/00/11/001153d2a22d889837efac1703e10a5e.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Eleanor & Park',
#   'Rating': 'Five',
#   'Price': 'Â£56.51',
#   'Images': '../media/cache/ed/d7/edd781d3c9d63a395f80f241445e88fa.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Dirty (Dive Bar #1)',
#   'Rating': 'Four',
#   'Price': 'Â£40.83',
#   'Images': '../media/cache/ae/90/ae903f6f6d059954be4e85497dd76bf5.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Can You Keep a Secret? (Fear Street Relaunch #4)',
#   'Rating': 'One',
#   'Price': 'Â£48.64',
#   'Images': '../media/cache/0b/2f/0b2f432cc27132f688fcdf29618521e0.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Boar Island (Anna Pigeon #19)',
#   'Rating': 'Three',
#   'Price': 'Â£59.48',
#   'Images': '../media/cache/d5/81/d58157866ea8f015a8e4c55b23b8c96f.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'A Paris Apartment',
#   'Rating': 'Four',
#   'Price': 'Â£39.01',
#   'Images': '../media/cache/16/57/16575316618bd7e922d5b0e0f87de2ca.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'A la Mode: 120 Recipes in 60 Pairings: Pies, Tarts, Cakes, Crisps, and More Topped with Ice Cream, Gelato, Frozen Custard, and More',
#   'Rating': 'One',
#   'Price': 'Â£38.77',
#   'Images': '../media/cache/98/19/9819ff3a8290dc6ab8797d00de5ec554.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Troublemaker: Surviving Hollywood and Scientology',
#   'Rating': 'Two',
#   'Price': 'Â£48.39',
#   'Images': '../media/cache/77/82/778285b3c87d6d5d98003aa0f2f65933.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'The Widow',
#   'Rating': 'Two',
#   'Price': 'Â£27.26',
#   'Images': '../media/cache/fd/71/fd71fb07247bf911505a351c0670c6dc.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'The Sleep Revolution: Transforming Your Life, One Night at a Time',
#   'Rating': 'Four',
#   'Price': 'Â£11.68',
#   'Images': '../media/cache/3d/c5/3dc5455313710cf7055c060114e25bf0.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'The Improbability of Love',
#   'Rating': 'One',
#   'Price': 'Â£59.45',
#   'Images': '../media/cache/06/49/06493269f6893cfd24b650f66df51882.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'The Art of Startup Fundraising',
#   'Rating': 'Three',
#   'Price': 'Â£21.00',
#   'Images': '../media/cache/b3/7b/b37be83183f1dcb759d92bda8f8998a4.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Take Me Home Tonight (Rock Star Romance #3)',
#   'Rating': 'Three',
#   'Price': 'Â£53.98',
#   'Images': '../media/cache/a6/4b/a64b3c559f59748bfdbbe75be3e16075.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Sleeping Giants (Themis Files #1)',
#   'Rating': 'One',
#   'Price': 'Â£48.74',
#   'Images': '../media/cache/c0/72/c072c1ef144d571abd25fe9cc18cceba.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Setting the World on Fire: The Brief, Astonishing Life of St. Catherine of Siena',
#   'Rating': 'Two',
#   'Price': 'Â£21.15',
#   'Images': '../media/cache/8b/c4/8bc43a6b42d0283ab4bf611f1b497126.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Playing with Fire',
#   'Rating': 'Three',
#   'Price': 'Â£13.71',
#   'Images': '../media/cache/90/0b/900bd2e60d56b6480a4e8eb2dddb46d6.jpg',
#   'Stock': 'In stock'},
#  {'Name': 'Off the Hook (Fishing for Trouble #1)',
#   'Rating': 'Three',
#   'Price': 'Â£47.67',
#   'Images': '../media/cache/1d/78/1d78fe226e1adb9cb591fa21f8a9bf68.jpg',
#   'Stock': 'In stock'}]

# %%
data = pd.DataFrame(ALL_products)

# %% [markdown]
# # Scraped Data

# %%
data
# Out:
#                                                   Name Rating    Price  \
# 0                                 A Light in the Attic  Three  Â£51.77
# 1                                   Tipping the Velvet    One  Â£53.74
# 2                                           Soumission    One  Â£50.10
# 3                                        Sharp Objects   Four  Â£47.82
# 4                Sapiens: A Brief History of Humankind   Five  Â£54.23
# ..                                                 ...    ...      ...
# 395        Take Me Home Tonight (Rock Star Romance #3)  Three  Â£53.98
# 396                  Sleeping Giants (Themis Files #1)    One  Â£48.74
# 397  Setting the World on Fire: The Brief, Astonish...    Two  Â£21.15
# 398                                  Playing with Fire  Three  Â£13.71
# 399              Off the Hook (Fishing for Trouble #1)  Three  Â£47.67
#
#                                                 Images     Stock
# 0    ../media/cache/2c/da/2cdad67c44b002e7ead0cc356...  In stock
# 1    ../media/cache/26/0c/260c6ae16bce31c8f8c95dadd...  In stock
# 2    ../media/cache/3e/ef/3eef99c9d9adef34639f51066...  In stock
# 3    ../media/cache/32/51/3251cf3a3412f53f339e42cac...  In stock
# 4    ../media/cache/be/a5/bea5697f2534a2f86a3ef27b5...  In stock
# ..                                                 ...       ...
# 395  ../media/cache/a6/4b/a64b3c559f59748bfdbbe75be...  In stock
# 396  ../media/cache/c0/72/c072c1ef144d571abd25fe9cc...  In stock
# 397  ../media/cache/8b/c4/8bc43a6b42d0283ab4bf611f1...  In stock
# 398  ../media/cache/90/0b/900bd2e60d56b6480a4e8eb2d...  In stock
# 399  ../media/cache/1d/78/1d78fe226e1adb9cb591fa21f...  In stock
#
# [400 rows x 5 columns]

# %% [markdown]
# # Data Saved in "products.csv" file

# %%
data.to_csv("products.csv", index = False)

# %%
os.makedirs("images", exist_ok=True)  
img_url = str(data["Images"].iloc[0])  
if not img_url.startswith("http"):
    img_url = url + img_url 
img_data = requests.get(img_url).content
img_name = os.path.join("images", img_url.split("/")[-1])  

with open(img_name, "wb") as img_file:
    img_file.write(img_data)

print(f"Downloaded {img_name}")
# Out:
# Downloaded images\2cdad67c44b002e7ead0cc35693c0e8b.jpg
